# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master' +
                 '/New_York_offenses/NEW_YORK-Offenses_Known_to_Law_Enforcement_by_City_2013%20-%2013tbl8ny.csv')
df = df.drop([0,1,2])

df = df.rename(columns=df.iloc[0])
df = df.rename(columns = {'Murder and\nnonnegligent\nmanslaughter':'Murder'})
df = df.drop([3])
df = df.reset_index(drop = True)

# %%
# Create a Feature dataframe
features = pd.DataFrame()

# Change Population from object to int
df['Population'] = df['Population'].str.replace(',', '')
df['Population'] = pd.to_numeric(df['Population']).astype(float)

# Set up 'Murder' and 'Robbery' for later use
df['Murder'] = df['Murder'].str.replace(',', '')
df['Murder'] = df['Murder'].dropna()

df['Robbery'] = df['Robbery'].str.replace(',', '')
df['Robbery'] = df['Robbery'].dropna()

# %%
# set 'Population' and 'Population^2' as feature
features['Population'] = df['Population']
features['Population^2'] = df['Population']**2

# %%
# set 'Murder' and 'Robbery' as feature
# coded any number > 0 as 1
# coded any number = 0 as 0
features['Murder'] = df['Murder']
features['Murder'] = features['Murder'].str.contains('0').apply(lambda x:0 if x else 1)

features['Robbery'] = df['Robbery']
features['Robbery'] = features['Robbery'].str.contains('0').apply(lambda x:0 if x else 1)

# %%
features
# Out:
#      Population  Population^2  Murder  Robbery
# 0        1861.0  3.463321e+06       0        0
# 1        2577.0  6.640929e+06       0        0
# 2        2846.0  8.099716e+06       0        0
# 3       97956.0  9.595378e+09       1        1
# 4        6388.0  4.080654e+07       0        1
# 5        4089.0  1.671992e+07       0        1
# 6        1781.0  3.171961e+06       0        0
# 7      118296.0  1.399394e+10       1        1
# 8        9519.0  9.061136e+07       0        1
# 9       18182.0  3.305851e+08       0        1
# 10       2053.0  4.214809e+06       0        0
# 11       4523.0  2.045753e+07       0        1
# 12        658.0  4.329640e+05       0        0
# 13       2522.0  6.360484e+06       0        0
# 14      27270.0  7.436529e+08       1        1
# 15       3333.0  1.110889e+07       0        1
# 16       7473.0  5.584573e+07       0        1
# 17       5418.0  2.935472e+07       0        1
# 18      15374.0  2.363599e+08       0        1
# 19       5733.0  3.286729e+07       0        1
# 20      17627.0  3.107111e+08       0        1
# 21      34243.0  1.172583e+09       0        1
# 22      46304.0  2.144060e+09       1        0
# 23       1410.0  1.988100e+06       0        0
# 24      12001.0  1.440240e+08       0        0
# 25       1022.0  1.044484e+06       0        0
# 26       2325.0  5.405625e+06       0        0
# 27       2054.0  4.218916e+06       0        0
# 28       2065.0  4.264225e+06       0        1
# 29       2358.0  5.560164e+06       0        0
# ..          ...           ...     ...      ...
# 321     61686.0  3.805163e+09       1        0
# 322     27980.0  7.828804e+08       0        1
# 323      6887.0  4.743077e+07       1        1
# 324     27940.0  7.806436e+08       0        1
# 325      3012.0  9.072144e+06       0        0
# 326      3453.0  1.192321e+07       0        0
# 327      5828.0  3.396558e+07       0        1
# 328      8392.0  7.042566e+07       0        0
# 329      5175.0  2.678062e+07       0        1
# 330     28179.0  7.940560e+08       0        1
# 331     10245.0  1.049600e+08       1        1
# 332      1862.0  3.467044e+06       0        0
# 333      4337.0  1.880957e+07       0        1
# 334     43777.0  1.916426e+09       0        1
# 335      1797.0  3.229209e+06       0        0
# 336      4574.0  2.092148e+07       0        0
# 337      1732.0  2.999824e+06       0        0
# 338     44821.0  2.008922e+09       1        1
# 339      2604.0  6.780816e+06       0        0
# 340     57559.0  3.313038e+09       1        1
# 341      3733.0  1.393529e+07       0        0
# 342      9141.0  8.355788e+07       0        0
# 343     10685.0  1.141692e+08       0        1
# 344       829.0  6.872410e+05       0        0
# 345      5931.0  3.517676e+07       0        0
# 346    199134.0  3.965435e+10       1        0
# 347     36643.0  1.342709e+09       0        1
# 348         NaN           NaN       0        0
# 349         NaN           NaN       0        0
# 350         NaN           NaN       0        0
#
# [351 rows x 4 columns]
